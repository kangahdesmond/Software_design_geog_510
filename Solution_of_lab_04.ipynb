# %% [markdown]
# <a href="https://colab.research.google.com/github/kangahdesmond/Software_design_geog_510/blob/main/Solution_of_lab_04.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Lab 4
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/giswqs/geog-510/blob/main/book/labs/lab_04.ipynb)

# %% [markdown]
# ## Exercise 1: Variable Assignment and Basic Operations
#
# Create variables to store the following geospatial data:
#
# - The latitude and longitude of New York City: 40.7128, -74.0060.
# - The population of New York City: 8,336,817.
# - The area of New York City in square kilometers: 783.8.
#
# Perform the following tasks:
#
# 1. Calculate and print the population density of New York City (population per square kilometer).
# 2. Print the coordinates in the format "Latitude: [latitude], Longitude: [longitude]".

# %% [markdown]
# **Defining Parameters**

# %%
NYC_lat = 40.7128
NYC_lon = -74.0060
NYC_pop = 8336817
NYC_area = 783.8

# %%
population = 8336817
area = 783.8
density = population / area
print(f"The popuplation density: {density}")
# Out:
# The popuplation density: 10636.408522582293

# %%
print("Latitude: {}, Longitude: {}".format(NYC_lat, NYC_lon))
# Out:
# Latitude: 40.7128, Longitude: -74.006

# %% [markdown]
# ## Exercise 2: Working with Strings
#
# Create a string variable to store the name of a city, such as "San Francisco". Perform the following operations:
#
# 1. Convert the string to lowercase and print the result.
# 2. Convert the string to uppercase and print the result.
# 3. Replace "San" with "Los" in the city name and print the new string.

# %% [markdown]
# **Exercise 2.1**

# %%
Lower_case = "San Francisco".lower()
print(Lower_case)
# Out:
# san francisco

# %% [markdown]
# **Exercise 2.2**

# %%
Upper_case = "San Francisco".upper()
print(Upper_case)
# Out:
# SAN FRANCISCO

# %% [markdown]
# **Exercise 2.3**

# %%
Name = "San Francisco"
New_Name = Name.replace("San", "Los")
print(New_Name)
# Out:
# Los Francisco

# %% [markdown]
# ## Exercise 3: Using Lists
#
# Create a list of tuples, where each tuple contains the name of a city and its corresponding latitude and longitude:
#
# - New York City: (40.7128, -74.0060)
# - Los Angeles: (34.0522, -118.2437)
# - Chicago: (41.8781, -87.6298)
#
# Perform the following tasks:
#
# 1. Add a new city (e.g., Miami: (25.7617, -80.1918)) to the list.
# 2. Print the entire list of cities.
# 3. Slice the list to print only the first two cities.

# %%
cities = [
    ("New York City", 40.7128, -74.0060),
    ("Los Angeles", 34.0522, -118.2437),
    ("Chicago", 41.8781, -87.6298)
]

# %%
cities.append(("Miami", 25.7617, -80.1918))

# %%
print("The updated cities are :", cities)
# Out:
# The updated cities are : [('New York City', 40.7128, -74.006), ('Los Angeles', 34.0522, -118.2437), ('Chicago', 41.8781, -87.6298), ('Miami', 25.7617, -80.1918)]

# %%
sliced_cities = cities[:2]
print("The sliced cities are :", sliced_cities)
# Out:
# The sliced cities are : [('New York City', 40.7128, -74.006), ('Los Angeles', 34.0522, -118.2437)]

# %% [markdown]
# ## Exercise 4: Using Tuples
#
# Create a tuple to store the coordinates (latitude, longitude) of the Eiffel Tower: (48.8584, 2.2945). Perform the following tasks:
#
# 1. Access and print the latitude and longitude values from the tuple.
# 2. Try to change the latitude value to 48.8585. What happens? Explain why.

# %%
Eiffel_Tower = (
    48.8584,
    2.2945
    )

# %%
latitude = Eiffel_Tower[0]
longitude = Eiffel_Tower[1]
print(f"The latitude is {latitude} and the longitude is {longitude}")
# Out:
# The latitude is 48.8584 and the longitude is 2.2945

# %%
Eiffel_Tower[0] = 48.8585
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-51-9186534d720e> in <cell line: 0>()
# ----> 1 Eiffel_Tower[0] = 48.8585
#
# TypeError: 'tuple' object does not support item assignment

# %% [markdown]
# #### **Explanation**: Tuples are immutable, meaning their elements cannot be changed after creation.

# %% [markdown]
# ## Exercise 5: Working with Sets
#
# Create a set of countries you have visited, such as {"USA", "France", "Germany"}. Perform the following tasks:
#
# 1. Add a new country to the set.
# 2. Try to add the same country again. What happens?
# 3. Print the updated set.

# %%
Countries_visited = ["USA", "France", "Germany"]
Countries_visited = set(Countries_visited)

# %% [markdown]
# **Exercise 5.1**

# %%
Countries_visited.add("Canada")
print(Countries_visited)
# Out:
# {'Canada', 'Germany', 'USA', 'France'}

# %% [markdown]
# **Exercise 5.2**

# %%
Countries_visited.add("Canada")
print(Countries_visited)
# Out:
# {'Canada', 'Germany', 'USA', 'France'}

# %% [markdown]
# After adding the same country again, nothing change and there was no duplicate

# %% [markdown]
# ## Exercise 6: Working with Dictionaries
#
# Create a dictionary to store information about a specific geospatial feature, such as a river:
#
# - Name: "Amazon River"
# - Length: 6400 km
# - Countries: ["Brazil", "Peru", "Colombia"]
#
# Perform the following tasks:
#
# 1. Add a new key-value pair to the dictionary to store the river's average discharge (e.g., 209,000 m³/s).
# 2. Update the length of the river to 6992 km.
# 3. Print the dictionary.

# %%
river = {
    "Name": "Amazon River",
    "Length": 6400,
    "Countries": ["Brazil", "Peru", "Colombia"]
}

# %% [markdown]
# **Exercise 6.1**

# %%
river["Average Discharge"] = 209000

# %% [markdown]
# **Exercise 6.2**

# %%
river["Length"] = 6992

# %% [markdown]
# **Exercise 6.3**

# %%
print(river)
# Out:
# {'Name': 'Amazon River', 'Length': 6992, 'Countries': ['Brazil', 'Peru', 'Colombia'], 'Average Discharge': 209000}

# %% [markdown]
# ## Exercise 7: Nested Data Structures
#
# Create a dictionary to represent a city that contains the city's name, population, and coordinates (latitude, longitude):
#
# - Name: "Tokyo"
# - Population: 13,515,271
# - Coordinates: (35.6895, 139.6917)
#
# Perform the following tasks:
#
# 1. Access and print the population of the city.
# 2. Access and print the city's latitude.
# 3. Update the population to 14,000,000 and print the updated dictionary.

# %%
city = {
    "Name": "Tokyo",
    "Population": 13515271,
    "Coordinates": (35.6895, 139.6917)
}

# %% [markdown]
# **Exercise 7.1**

# %%
City_Population = city["Population"]
print(City_Population)
# Out:
# 13515271

# %% [markdown]
# **Exercise 7.2**

# %%
City_latitude = city['Coordinates'][0]
print("The City latitude is: ", City_latitude)
# Out:
# The City latitude is:  35.6895

# %% [markdown]
# ## Exercise 8: List Operations
#
# Given the list of cities from Exercise 3, perform the following operations:
#
# 1. Sort the list of cities alphabetically by name.
# 2. Create a new list that contains only the city names.
# 3. Remove the last city from the original list and print the updated list.

# %% [markdown]
# **Exercise 8.1**

# %%
cities.sort()
print("Sorted list of cities:", cities)
# Out:
# Sorted list of cities: [('Chicago', 41.8781, -87.6298), ('Los Angeles', 34.0522, -118.2437), ('Miami', 25.7617, -80.1918), ('New York City', 40.7128, -74.006)]

# %% [markdown]
# **Exercise 8.2**

# %%
city_names = [city[0] for city in cities]
print("List of city names:", city_names)
# Out:
# List of city names: ['Chicago', 'Los Angeles', 'Miami', 'New York City']

# %%
cities.pop()
print("Updated list of cities:", cities)
# Out:
# Updated list of cities: [('Chicago', 41.8781, -87.6298), ('Los Angeles', 34.0522, -118.2437), ('Miami', 25.7617, -80.1918)]

# %% [markdown]
# ## Exercise 9: Dictionary Operations
#
# Using the dictionary from Exercise 6, perform the following tasks:
#
# 1. Check if the key "Length" exists in the dictionary.
# 2. Print all the keys in the dictionary.
# 3. Print all the values in the dictionary.

# %% [markdown]
# **Exercise 9.1**

# %%
if "Length" in river:
  print("Yes, 'Length' key exists in the dictionary")
# Out:
# Yes, 'Length' key exists in the dictionary

# %% [markdown]
# **Exercise 9.2**

# %%
print("Keys:", river.keys())
# Out:
# Keys: dict_keys(['Name', 'Length', 'Countries', 'Average Discharge'])

# %% [markdown]
# **Exercise 9.3**

# %%
print("Values:", river.values())
# Out:
# Values: dict_values(['Amazon River', 6992, ['Brazil', 'Peru', 'Colombia'], 209000])

# %% [markdown]
# ## Exercise 10: Practical Application
#
# Imagine you have a list of tuples, each representing a location with its name, latitude, and longitude:

# %%
locations = [
    ("Mount Everest", 27.9881, 86.9250),
    ("K2", 35.8808, 76.5155),
    ("Kangchenjunga", 27.7025, 88.1475),
]

# %% [markdown]
# Perform the following tasks:
#
# 1. Create a new list that contains only the names of the locations.
# 2. Create a dictionary where the keys are location names and the values are tuples of their coordinates.
# 3. Print the latitude of "K2" using the dictionary.

# %% [markdown]
# **Exercise 10.1**

# %%
location_names = [location[0] for location in locations]
print(location_names)
# Out:
# ['Mount Everest', 'K2', 'Kangchenjunga']

# %% [markdown]
# **Exercise 10.2**

# %%
location_dict = {}
for name, lat, lon in locations:
    location_dict[name] = (lat, lon)
print(location_dict)
# Out:
# {'Mount Everest': (27.9881, 86.925), 'K2': (35.8808, 76.5155), 'Kangchenjunga': (27.7025, 88.1475)}

# %% [markdown]
# **Exercise 10.3**

# %%
k2_latitude = location_dict["K2"][0]
print(f"The latitude of K2 is: {k2_latitude}")
# Out:
# The latitude of K2 is: 35.8808

# %% [markdown]
# ## Exercise 11: Manipulating Geographic Location Strings
#
# - Create a string that represents the name of a geographic feature (e.g., `"Amazon River"`).
# - Convert the string to lowercase and then to uppercase.
# - Concatenate the string with the name of the country (e.g., `"Brazil"`) to create a full location name.
# - Repeat the string three times, separating each repetition with a dash (`-`).

# %%
geographic_feature = "Amazon River"

lowercase_feature = geographic_feature.lower()
uppercase_feature = geographic_feature.upper()

print(f"Lowercase: {lowercase_feature}")
print(f"Uppercase: {uppercase_feature}")


country = "Brazil"
full_location_name = geographic_feature + ", " + country
print(f"Full location name: {full_location_name}")


repeated_string = "-".join([geographic_feature] * 3)
print(f"Repeated string: {repeated_string}")
# Out:
# Lowercase: amazon river
# Uppercase: AMAZON RIVER
# Full location name: Amazon River, Brazil
# Repeated string: Amazon River-Amazon River-Amazon River

# %% [markdown]
# ## Exercise 12: Extracting and Formatting Coordinates
#
# - Given a string with the format `"latitude, longitude"` (e.g., `"40.7128N, 74.0060W"`), extract the numeric values of latitude and longitude.
# - Convert these values to floats and remove the directional indicators (`N`, `S`, `E`, `W`).
# - Format the coordinates into a `POINT` WKT string (e.g., `"POINT(-74.0060 40.7128)"`).

# %%
coordinate_string = "40.7128N, 74.0060W"

latitude_str, longitude_str = coordinate_string.split(",")


latitude = float(latitude_str.strip()[:-1])
longitude = float(longitude_str.strip()[:-1])


wkt_point = f"POINT({longitude} {latitude})"

wkt_point
# Out:
# 'POINT(74.006 40.7128)'

# %% [markdown]
# ## Exercise 13: Building Dynamic SQL Queries
#
# - Given a table name and a condition, dynamically build an SQL query string.
# - Example: If `table_name = "cities"` and `condition = "population > 1000000"`, the query should be `"SELECT * FROM cities WHERE population > 1000000;"`.
# - Add additional conditions dynamically, like `AND` clauses.

# %%
table_name = "cities"
conditions = ["population > 1000000", "country = 'USA'"]
sql_query = f"SELECT * FROM {table_name} WHERE "
sql_query += " AND ".join(conditions) + ";"
print(sql_query)
# Out:
# SELECT * FROM cities WHERE population > 1000000 AND country = 'USA';

# %% [markdown]
# ## Exercise 14: String Normalization and Cleaning
#
# - Given a list of city names with inconsistent formatting (e.g., `[" new york ", "Los ANGELES", "   CHICAGO"]`), normalize the names by:
#   - Stripping any leading or trailing whitespace.
#   - Converting them to title case (e.g., `"New York"`, `"Los Angeles"`, `"Chicago"`).
# - Ensure that the output is a clean list of city names.

# %%
city_names = [" new york ", "Los ANGELES", "   CHICAGO"]
normalized_city_names = [city.strip().title() for city in city_names]
normalized_city_names
# Out:
# ['New York', 'Los Angeles', 'Chicago']

# %% [markdown]
# ## Exercise 15: Parsing and Extracting Address Information
#
# - Given a string in the format `"Street, City, Country"` (e.g., `"123 Main St, Springfield, USA"`), write a function that parses the string into a dictionary with keys `street`, `city`, and `country`.
# - The function should return a dictionary like `{"street": "123 Main St", "city": "Springfield", "country": "USA"}`.

# %%
def parse_address(address_string):
    parts = address_string.split(",")
    if len(parts) == 3:
        street, city, country = parts
        return {
            "street": street.strip(),
            "city": city.strip(),
            "country": country.strip()
        }
    else:
        return None

address_string = "123 Main St, Springfield, USA"
address_info = parse_address(address_string)
address_info
# Out:
# {'street': '123 Main St', 'city': 'Springfield', 'country': 'USA'}

# %% [markdown]
# ## Exercise 16: Using For Loops to Process Coordinate Lists
#
# - Create a list of tuples representing coordinates (latitude, longitude).
# - Write a `for` loop that prints each coordinate and indicates whether it is in the Northern or Southern Hemisphere based on the latitude.

# %%
coordinates = [(40.7128, -74.0060), (-34.6037, -58.3816), (35.6895, 139.6917)]

for lat, lon in coordinates:
    if lat >= 0:
        hemisphere = "Northern"
    else:
        hemisphere = "Southern"
    print(f"Coordinates: ({lat}, {lon}) - {hemisphere} Hemisphere")
# Out:
# Coordinates: (40.7128, -74.006) - Northern Hemisphere
# Coordinates: (-34.6037, -58.3816) - Southern Hemisphere
# Coordinates: (35.6895, 139.6917) - Northern Hemisphere

# %% [markdown]
# ## Exercise 17: While Loops for Iterative Processing
#
# - Create a list of coordinates (latitude, longitude).
# - Write a `while` loop that continues to print each coordinate until it encounters a coordinate with a negative latitude.
# - Stop the loop once this condition is met.

# %%
coordinates = [(40.7128, -74.0060), (-34.6037, -58.3816), (35.6895, 139.6917)]
i = 0
while i < len(coordinates) and coordinates[i][0] >= 0:
    lat, lon = coordinates[i]
    print(f"Coordinates: ({lat}, {lon})")
    i += 1
# Out:
# Coordinates: (40.7128, -74.006)

# %% [markdown]
# ## Exercise 18: Conditional Logic in Loops
#
# - Create a list of coordinates and use a `for` loop to iterate over them.
# - Use an `if-elif-else` statement inside the loop to classify each coordinate based on its longitude:
#   - Print `"Eastern Hemisphere"` if the longitude is greater than 0.
#   - Print `"Western Hemisphere"` if the longitude is less than 0.

# %%
coordinates = [(40.7128, -74.0060), (-34.6037, -58.3816), (35.6895, 139.6917)]

for lat, lon in coordinates:
  if lon > 0:
    print("Eastern Hemisphere")
  elif lon < 0:
    print("Western Hemisphere")
  else:
    print("Prime Meridian")
# Out:
# Western Hemisphere
# Western Hemisphere
# Eastern Hemisphere

# %% [markdown]
# ## Exercise 19: Filtering Data with Combined Loops and Conditionals
#
# - Given a list of coordinates, filter out and store only those located in the Southern Hemisphere (latitude < 0).
# - Count the number of coordinates that meet this condition and print the result.

# %%
coordinates = [(40.7128, -74.0060), (-34.6037, -58.3816), (35.6895, 139.6917)]

southern_hemisphere_coordinates = []
count = 0

for lat, lon in coordinates:
  if lat < 0:
    southern_hemisphere_coordinates.append((lat, lon))
    count += 1

print(f"Number of coordinates in the Southern Hemisphere: {count}")
print(f"Coordinates in the Southern Hemisphere: {southern_hemisphere_coordinates}")
# Out:
# Number of coordinates in the Southern Hemisphere: 1
# Coordinates in the Southern Hemisphere: [(-34.6037, -58.3816)]

# %% [markdown]
# ## Exercise 20: Generating and Analyzing Random Coordinates
#
# - Write a program that generates random coordinates (latitude between [-90, 90] degrees and longitude between [-180, 180] degrees).
# - Use a `while` loop to keep generating coordinates until a pair with both latitude and longitude greater than 50 is generated.
# - Print each generated coordinate and the final coordinate that meets the condition.

# %%
import random

latitude = random.uniform(-90, 90)
longitude = random.uniform(-180, 180)

while latitude <= 50 or longitude <= 50:
    latitude = random.uniform(-90, 90)
    longitude = random.uniform(-180, 180)
    print(f"Generated coordinates: Latitude = {latitude}, Longitude = {longitude}")

print(f"Final coordinates (both greater than 50): Latitude = {latitude}, Longitude = {longitude}")
# Out:
# Generated coordinates: Latitude = -12.601322739846069, Longitude = -130.70660362823094
# Generated coordinates: Latitude = 18.000558891805625, Longitude = 34.82627498770219
# Generated coordinates: Latitude = 57.423361901046775, Longitude = -149.18394272371148
# Generated coordinates: Latitude = 73.3678345619901, Longitude = 86.33704533443148
# Final coordinates (both greater than 50): Latitude = 73.3678345619901, Longitude = 86.33704533443148

# %% [markdown]
# ## Submission Requirements
#
# Complete the exercises above and and upload the notebook to your GitHub repository. Make sure the notebook has a Colab badge at the top so that it can be easily opened in Google Colab. Submit the URL of the notebook to Canvas.
