# %% [markdown]
# ## **Introduction to Jupyter Notebook**

# %%
import os

# %%
print("ANimal the Kangaroo")
# Out:
# ANimal the Kangaroo

# %%
print("The other try work, the try works and other things together")
# Out:
# The other try work, the try works and other things together

# %%
print("THe code and the new update to the github")
# Out:
# THe code and the new update to the github
